# %%
# tuples

# %%
list2 = [1,2,3]

# %%
id(list2)
# Out:
# 139110863159936

# %%
list2[1] = 100

# %%
list2
# Out:
# [1, 100, 3]

# %%
id(list2)
# Out:
# 139110863159936

# %%
tuple_1 = (1,2,3)

# %%
type(tuple_1)
# Out:
# tuple

# %%
id(tuple_1)
# Out:
# 139110863286528

# %%
tuple_1 = (1,100,3)

# %%
id(tuple_1)
# Out:
# 139110435389760

# %%
tuple_1[0:2]
# Out:
# (1, 100)

# %%
for i in tuple_1:
    print(i)
# Out:
# 1
# 100
# 3

# %%
def funcc():
  return 30,"obese"

# %%
funcc()
# Out:
# (30, 'obese')

# %%
empty_list = []

# %%
type(empty_list)
# Out:
# list

# %%
empty_tup = ()

# %%
type(empty_tup)
# Out:
# tuple

# %%
tuple_2 = (56,)

# %%
type(tuple_2)
# Out:
# tuple

# %%
(50,50.6,True,"string",[1,2,3],(7,8,9),None)
# Out:
# (50, 50.6, True, 'string', [1, 2, 3], (7, 8, 9), None)

# %%
a = 10
b = 20

# %%
temp = a
a=b
b=temp

# %%
a,b = b,a # unpacking

# %%
a,b
# Out:
# (20, 10)

# %%
funcc()
# Out:
# (30, 'obese')

# %%
bmi,classify = funcc()

# %%
bmi
# Out:
# 30

# %%
classify
# Out:
# 'obese'

# %%
tupl5 = (50,50,True,"string",[1,2,3],(7,8,9),None)

# %%
tupl5.count(50)
# Out:
# 2

# %%
tupl5.index("string")
# Out:
# 3

# %%
# sets

# %%
set1 = {1,1,1,2,3,111,5,6,6,89,9,9,2}

# %%
set1
# Out:
# {1, 2, 3, 5, 6, 9, 89, 111}

# %%
# set1[0]

# %%
id(set1)
# Out:
# 139110435106688

# %%
set1.add(116)

# %%
set1
# Out:
# {1, 2, 3, 5, 6, 9, 89, 111, 116}

# %%
id(set1)
# Out:
# 139110435106688

# %%
set1.remove(111)

# %%
set1
# Out:
# {1, 2, 3, 5, 6, 9, 89, 116}

# %%
# set1.remove(112)

# %%
set1.discard(112)

# %%
set_A = {1,2,3}
set_B = {3,4,5}

# %%
set_A.intersection(set_B) # A n B
# Out:
# {3}

# %%
set_A & set_B # A n B
# Out:
# {3}

# %%
set_A.union(set_B) # A U B
# Out:
# {1, 2, 3, 4, 5}

# %%
set_A | (set_B) # A U B
# Out:
# {1, 2, 3, 4, 5}

# %%
set_A.difference(set_B)
# Out:
# {1, 2}

# %%
set_B.difference(set_A)
# Out:
# {4, 5}

# %%
set_A - set_B
# Out:
# {1, 2}

# %%
set_B.symmetric_difference(set_A)
# Out:
# {1, 2, 4, 5}

# %%
setA = {1,2}
setB = {1,2,3}

# %%
setA.issubset(setB)
# Out:
# True

# %%
setB.issuperset(setA)
# Out:
# True

# %% [markdown]
# 1. **Remove Duplicates from a List**:
#     - **Problem**: Given a list, return a new list with duplicates removed.
#     - **Example**: For `[1, 2, 2, 3, 4, 4]`, return `[1, 2, 3, 4]`.

# %%
list5 = [1, 2, 2, 3, 4, 4]

# %%
list(set(list5))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 2. **Find Common Elements Between Two Lists**:a
#     - **Problem**: Given two lists, find and return their intersection (common elements).
#     - **Example**: For `[1, 2, 3]` and `[2, 3, 4]`, the result should be `{2, 3}`.

# %%
set([1, 2, 3]).intersection(set([2, 3, 4]))
# Out:
# {2, 3}
