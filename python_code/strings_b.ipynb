# %%
valid_string = "this is a python class"

# %%
valid_string
# Out:
# 'this is a python class'

# %%
"dsfghjk456145678$%^&*()"
# Out:
# 'dsfghjk456145678$%^&*()'

# %%
id(valid_string)
# Out:
# 139742308624112

# %%
valid_string = "this is a python class CHANGED STRING"

# %%
id(valid_string)
# Out:
# 139742296439568

# %%
'more ways of wrting'
# Out:
# 'more ways of wrting'

# %%
# 'more ways of wrting"

# %%
'''
multiple
lines

'''
# Out:
# '\nmultiple\nlines\n\n'

# %%
# commenting

# %% [markdown]
#  write code using html in markdown

# %%
"ACH" < "ZHM"
# Out:
# True

# %%
# lexicograhpic order

# %%
ord("A")
# Out:
# 65

# %%
ord("Z")
# Out:
# 90

# %%
chr(65)
# Out:
# 'A'

# %%
"A" + "B"
# Out:
# 'AB'

# %%
"A" + "B"
# Out:
# 'AB'

# %%
"AB" * 5
# Out:
# 'ABABABABAB'

# %%
# AB + AB + AB + AB + AB

# %%
"\U0001F923"
# Out:
# '🤣'

# %%
length = 50
breadth = 10
area = length * breadth

# %%
print("Length of rect is > ",length,"\nBreadth of rect is > ",breadth,"\nArea of rect is > ",area)
# Out:
# Length of rect is >  50
# Breadth of rect is >  10
# Area of rect is >  500

# %%
print("Length of rect is > {},\nBreadth of rect is > {},\nArea of rect is > {}".format(length,breadth,area))
# Out:
# Length of rect is > 50,
# Breadth of rect is > 10,
# Area of rect is > 500

# %%
print(f"Length of rect is > {length},\nBreadth of rect is > {breadth} ,\nArea of rect is > {area}")
# Out:
# Length of rect is > 50,
# Breadth of rect is > 10 ,
# Area of rect is > 500

# %%
valid_string
# Out:
# 'this is a python class CHANGED STRING'

# %%
valid_string[-6]
# Out:
# 'S'

# %%
valid_string[0:4]
# Out:
# 'this'

# %%
valid_string[-2:]
# Out:
# 'NG'

# %%
valid_string.split()
# Out:
# ['this', 'is', 'a', 'python', 'class', 'CHANGED', 'STRING']

# %%
valid_string.split("s")
# Out:
# ['thi', ' i', ' a python cla', '', ' CHANGED STRING']

# %%
list_strings = ['this', 'is', 'a', 'python', 'class', 'CHANGED', 'STRING']

# %%
"_".join(list_strings)
# Out:
# 'this_is_a_python_class_CHANGED_STRING'

# %%
valid_string.find("pyt")
# Out:
# 10

# %%
valid_string
# Out:
# 'this is a python class CHANGED STRING'

# %%
valid_string.replace("python","SQL")
# Out:
# 'this is a SQL class CHANGED STRING'

# %%
"class" in valid_string
# Out:
# True

# %%
list("class")
# Out:
# ['c', 'l', 'a', 's', 's']

# %%
valid_string
# Out:
# 'this is a python class CHANGED STRING'

# %%
valid_string.isdigit()
# Out:
# False

# %%
"45645".isdigit()
# Out:
# True

# %%
"dvsfdfgh".isalpha()
# Out:
# True

# %%
"sdfg456".isalnum()
# Out:
# True

# %%
"sdfgdfjk".islower()
# Out:
# True

# %%
"DFG".isupper()
# Out:
# True

# %%
valid_string.lower()
# Out:
# 'this is a python class changed string'

# %%
valid_string.upper()
# Out:
# 'THIS IS A PYTHON CLASS CHANGED STRING'

# %%
valid_string.title()
# Out:
# 'This Is A Python Class Changed String'

# %%
valid_string.swapcase()
# Out:
# 'THIS IS A PYTHON CLASS changed string'

# %%
valid_string.capitalize()
# Out:
# 'This is a python class changed string'

# %%
valid_string
# Out:
# 'this is a python class CHANGED STRING'

# %%
# You are given lowercase string (A) and you have to tell the count of vowels and consonants in it.else return `0`.

# %%
"a" in "aeiou"
# Out:
# True

# %%
# "gmail5" >> vowels = 2 , consonants = 3

# %%
def count_vowels_consonants(string):
    vowels = 0
    consonants = 0
    for char in string.lower():
        if char in "aeiou":
            vowels += 1
        elif char.isalpha():
            consonants += 1
    return vowels,consonants

# %%
count_vowels_consonants("GMAIL")
# Out:
# (2, 3)

# %% [markdown]
# Write a program to check whether two given strings are anagrams or not. Return **True** if the strings are anagrams else return **False.**
#
# **Note:** An anagram of a string is another string that contains the same characters, only the order of characters can be different.

# %%
sorted("silent")
# Out:
# ['e', 'i', 'l', 'n', 's', 't']

# %%
sorted("listen")
# Out:
# ['e', 'i', 'l', 'n', 's', 't']

# %%
def anagrams(S1,S2):
    if sorted(S1) == sorted(S2):
        print("it is an anagram")
    else:
        print("Not an anagram")

# %%
anagrams("silent","listen")
# Out:
# it is an anagram
