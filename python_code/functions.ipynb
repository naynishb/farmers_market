# %%
sum([9,8])
# Out:
# 17

# %%
min?

# %%
max(7,9)
# Out:
# 9

# %%
print("sdfg")
# Out:
# sdfg

# %%
## guests arrive

# %%
def guests_are_arriving(): # define
  print("dust all the rooms")
  print("Arrange living area")
  print("Get cold drinks")
  print("water bottles and snacks")

# %%
guests_are_arriving() # calling of func
# Out:
# dust all the rooms
# Arrange living area
# Get cold drinks
# water bottles and snacks

# %%
## guests are arriving second time

# %%
guests_are_arriving()
# Out:
# dust all the rooms
# Arrange living area
# Get cold drinks
# water bottles and snacks

# %%
guests_are_arriving()
# Out:
# dust all the rooms
# Arrange living area
# Get cold drinks
# water bottles and snacks

# %%
'''
Question 2 -
Take a name as input.
Write a greeter function which prints, "HELLO NAME!"
after accepting a name as argument.
'''
# Out:
# '\nQuestion 2 -\nTake a name as input.\nWrite a greeter function which prints, "HELLO NAME!"\nafter accepting a name as argument.\n'

# %%
def greeter(name):
  print("Hello",name,end = "!")

# %%
greeter("Naynish")
# Out:
# Hello Naynish!

# %%
name1 = input("Enter your name: ")
greeter(name1)
# Out:
# Enter your name: hj
# Hello hj!

# %%
print("fgh","dsf")
# Out:
# fgh dsf

# %%
def introduce_family(father,mother,sibling):
  print("My father's name is",father)
  print("My mother's name is",mother)
  print("My sibling's name is",sibling)

# %%
introduce_family("Shahrukh khan","Gauri","Suhana") # positional
# Out:
# My father's name is Shahrukh khan
# My mother's name is Gauri
# My sibling's name is Suhana

# %%
introduce_family("Gauri","Shahrukh khan","Suhana")
# Out:
# My father's name is Gauri
# My mother's name is Shahrukh khan
# My sibling's name is Suhana

# %%
# introduce_family("Shahrukh khan","Gauri","Suhana","Aryan")

# %%
# introduce_family("Shahrukh khan","Gauri")

# %%
introduce_family(mother = "Gauri",father = "Shahrukh khan",sibling= "Suhana")
# keyworded arguments
# Out:
# My father's name is Shahrukh khan
# My mother's name is Gauri
# My sibling's name is Suhana

# %%
# introduce_family(mother = "Gauri",father = "Shahrukh khan","Suhana")

# %%
introduce_family("Shahrukh khan",mother = "Gauri",sibling = "Suhana")
# Out:
# My father's name is Shahrukh khan
# My mother's name is Gauri
# My sibling's name is Suhana

# %%
def introduce_family(father = "NA",mother = "NA",sibling = "NA"):
  '''
  This function prints the family details
  Input Parameters:
  father - Name of the father
  mother - Name of the mother
  sibling - Name of the sibling
  Returns:
  Nothing

  '''
  print("My father's name is",father)
  print("My mother's name is",mother)
  print("My sibling's name is",sibling)

# %%
introduce_family("Shahrukh khan",mother = "Gauri",sibling = "Suhana")
# Out:
# My father's name is Shahrukh khan
# My mother's name is Gauri
# My sibling's name is Suhana

# %%
introduce_family("Shahrukh khan","Gauri")
# Out:
# My father's name is Shahrukh khan
# My mother's name is Gauri
# My sibling's name is NA

# %%
print?

# %%
introduce_family?

# %%
 '''
    Two arguments -
    Arguments can only be int or float.

    Output - Sum of both the arguments.
    '''
# Out:
# '\n   Two arguments -\n   Arguments can only be int or float.\n\n   Output - Sum of both the arguments.\n   '

# %%
def sum_of_two(x,y):
  '''
    Two arguments -
    Arguments can only be int or float.

    Output - Sum of both the arguments.
  '''
  return (x+y)

# %%
sum_of_two(5,4) + 100
# Out:
# 109

# %%
sum_of_two(8,9)
# Out:
# 17

# %%
def sum_of_two_2(x,y):
  '''
    Two arguments -
    Arguments can only be int or float.

    Output - Sum of both the arguments.
  '''
  return "this will be returned as a string",(x+y),(x-y)
  print("this will not print")

# %%
sum_of_two_2(8,9)
# Out:
# ('this will be returned as a string', 17, -1)

# %%
# a function that can take input as a number and tell if is odd or even

# %%
def odd_even(x):
  if x%2 == 0:
    return "even"
  else:
    return "odd"

# %%
odd_even(56)
# Out:
# 'even'

# %%
'''
Question 1 -
Create a date printing function -
Should take 4 arguments -> day, month, year and style

Styling Logic -
style -> 0 -> d/m/y
style -> 1 -> m/d/y
style -> any other value -> Invalid Style

default style is 0.
'''
# Out:
# '\nQuestion 1 -\nCreate a date printing function -\nShould take 4 arguments -> day, month, year and style\n\nStyling Logic -\nstyle -> 0 -> d/m/y\nstyle -> 1 -> m/d/y\nstyle -> any other value -> Invalid Style\n\ndefault style is 0.\n'

# %%
def data_printing_func(d,m,y,style = 0):
  if style == 0:
    print(d,m,y,sep = "/")
  elif style == 1:
    print(m,d,y,sep = "/")
  else:
    print("Invalid Style")

# %%
data_printing_func(19,5,2025,10)
# Out:
# Invalid Style

# %% [markdown]
# 1. Given the temperature of a day in Degrees Celsius, convert this given temperature from Celsius to Fahrenheit. Complete the function to do so. Round the output up to 2 decimal places
#
# **Note:**
#
# 1. To round up the values -
#     - Python : Use **round(ans,2)** to round up ans to two decimals
# 2. The formula to convert Celsius to Fahrenheit is: **F = (9/5 * C) + 32**

# %%
def celcius_to_fah(celcius):
  ans = (9/5 * celcius) + 32
  return round(ans,2)

# %%
celcius_to_fah(37)
# Out:
# 98.6

# %%
# input = radius of cirle, calculate area of circle

# %%
def area_of_circle(r):
  import math
  area = math.pi * (r**2)
  return round(area,2)

# %%
area_of_circle(10)
# Out:
# 314.16

# %% [markdown]
# 1. Write a program that takes the cost price of a vehicle as an argument and returns the road tax, that the vehicle owner has to pay according to the following criteria:
#
# ![](https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/481/original/cost_price.PNG?1650617485)
#
# **Note1**: Return the tax up to one decimal place. You can use `round(tax,1)`

# %%
def road_tax(cost_price):
  if cost_price > 100000:
    tax = 0.2 * cost_price
  elif cost_price > 75000 and cost_price <= 100000:
    tax = 0.15 * cost_price
  elif cost_price > 50000 and cost_price <= 75000:
    tax = 0.1 * cost_price
  else:
    tax = 0.05 * cost_price
  return round(tax,1)

# %%
road_tax(30000)
# Out:
# 1500.0

# %% [markdown]
# 1. Given the height **(A)** and weight **(B)** of a person as input in centimetres and kilograms.
#
# Find the BMI of that person and the classification of the user based on their BMI.
#
# 1. Print **Underweight** if BMI < 18.5
# 2. Print **Normal** if BMI lies in the range [18.5, 24.9]
# 3. Print **Overweight** if BMI lies in the range (24.9, 29.9]
# 4. Print **Obese** if BMI is greater than 29.9
#
# If **x** is the weight in kilograms and **y** is the height in metres.
#
# Then, BMI is calculated as **x/(y*y)**.
#
# **Note:** Use **round(BMI,1) to** get only one digit after decimal
#
# **Input Format -**
#
# The first line contains the height of the person in centimetres.
#
# The second line of the input contains the weight of the person in kilograms.
#
# **Output Format -**
#
# The first line of the output contains the classification of a person based on the BMI value.
#
# The second line of the output contains the BMI value of the person having only one digit after decimal.

# %%
def bmi_calculator(height_cm,weight_kg):
  height_m = height_cm/100
  bmi = weight_kg/(height_m**2)
  if bmi < 18.5:
    print("Underweight")
  elif bmi >= 18.5 and bmi <= 24.9:
    print("Normal")
  elif bmi > 24.9 and bmi <= 29.9:
    print("Overweight")
  else:
    print("Obese")
  print(round(bmi,1))

# %%
bmi_calculator(170,60)
# Out:
# Normal
# 20.8

# %%
def bmi_calculator2(height_cm,weight_kg):
  height_m = height_cm/100
  bmi = weight_kg/(height_m**2)
  if bmi < 18.5:
    print("Underweight")
  elif bmi >= 18.5 and bmi <= 24.9:
    print("Normal")
  elif bmi > 24.9 and bmi <= 29.9:
    print("Overweight")
  else:
    print("Obese")
  return (round(bmi,1))

# %%
bmi_calculator2(170,60)
# Out:
# Normal
# 20.8

# %%
# ternary operator

# %%
BMI = 40
if BMI < 18.5:
  print("UnderW")
else:
  print("Obese")
# Out:
# Obese

# %%
"UnderW" if BMI < 18.5 else "Obese"
# Out:
# 'Obese'

# %%
"Underweight" if bmi < 18.5 else "Normal" if bmi >= 18.5 and bmi <= 24.9 else "Overweight" if bmi > 24.9 and bmi <= 29.9 else "Obese"
# Out:
# 'Underweight'

# %%
bmi = 18

# %%
# lambda functions

# %%
# number is odd or even

# %%
def even_odd(x):
  if x % 2 == 0:
    print("Even")
  else:
    print("odd")

# %%
even_odd(5)
# Out:
# odd

# %%
even_odd2 = lambda x : "Even" if x % 2 == 0 else "Odd"

# %%
even_odd2(5)
# Out:
# 'Odd'

# %%
# add two numbers

# %%
add_two = lambda x,y : x + y

# %%
add_two(56,4)
# Out:
# 60

# %%
# square a number

# %%
square_a_number = lambda x : x**2

# %%
square_a_number(5)
# Out:
# 25

# %%
def bmi_calculator3(height_cm,weight_kg):
  height_m = height_cm/100
  bmi = weight_kg/(height_m**2)
  if bmi < 18.5:
    print("Underweight")
  elif bmi >= 18.5 and bmi <= 24.9:
    print("Normal")
  elif bmi > 24.9 and bmi <= 29.9:
    print("Overweight")
  else:
    print("Obese")
  return (round(bmi,1))

# %%
height_cm = int(input("Enter height in cm "))
weight_kg = int(input("Enter weight in kg "))
height_m = height_cm/100
bmi = weight_kg/(height_m**2)
bmi_calculator3 = lambda bmi: "Underweight" if bmi < 18.5 else "Normal" if bmi >= 18.5 and bmi <= 24.9 else "Overweight" if bmi > 24.9 and bmi <= 29.9 else "Obese"
print("you are",bmi_calculator3(bmi))
print("your bmi is",round(bmi))
# Out:
# Enter height in cm 180
# Enter weight in kg 70
# you are Normal
# your bmi is 22
